# %% [markdown]
# # Aula 01

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-2, 3, 100)
y = - 4*x**2 + 6*x - 1

plt.plot(x, y, label="f(x) = - 4x**2 +6x -1")
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.legend()
plt.show()

# %% [markdown]
# ## Exercícios para casa:

# %%
#Exercício 1
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-2, 3, 100)
y = -4*x**2 + 6*x - 1

plt.plot(x, y, label="f(x) = 4x**2 -6x -1")
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.legend()
plt.show()

# %%
#Exercício 2
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-2, 3, 100)

y = 25*x - 14

plt.plot(x, y, label="f(x) = 25x - 14")
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.legend()
plt.show()

# %% [markdown]
# # *Aula 03*

# %%
#Exemplo 01
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-2, 2, 100)
y1 = 1000 + (100* x)  # Crescimento
y2 = 1000 * (2 ** x)  # Decaimento

plt.plot(x, y1)
plt.plot(x, y2)
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.legend()
plt.title("Funções Exponenciais")
plt.show()
# Out:
# <ipython-input-5-ecf67aebf1e2>:13: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#Exemplo 01
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-2, 2, 100)
y1 = 1000 + (100* x)  # Crescimento
y2 = 1000 * (2 ** x)  # Decaimento

plt.plot(x, y1)
plt.plot(x, y2)
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.legend()
plt.title("Funções Exponenciais")
plt.show()
# Out:
# <ipython-input-1-ecf67aebf1e2>:13: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#Atividade iterativa Juros Compostos
P = 1000  # Capital inicial
r = 0.5  # Taxa de juros
t = np.arange(0, 10, 1)  # Tempo em anos

montante = P * (1 + r) ** t
plt.plot(t, montante, marker="o")
plt.title("Juros Compostos")
plt.xlabel("Tempo (anos)")
plt.ylabel("Montante (R$)")
plt.show()

# %% [markdown]
# # Aula 04

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0.1, 10, 100)
y1 = np.log2(x)
y2 = np.log10(x)
y3 = np.log(x)

plt.figure(figsize=(8,5))
plt.plot(x, y1, label='log_2(x)')
plt.plot(x, y2, label='log_10(x)')
plt.plot(x, y3, label='ln(x)')
plt.axhline(0, color='black', linewidth=1)
plt.axvline(1, color='black', linestyle='--')
plt.legend()
plt.title('Gráficos de Funções Logarítmicas')
plt.show()
